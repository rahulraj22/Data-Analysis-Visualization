# %%
import pandas as pd

# %%
df = pd.read_csv('suicide_dataset.csv')

# %%
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# Here, we can see that there is data begining from 1987 and so on but we need data from 2010, so to do ?
mask1 = df.year >= 2010
df.loc[mask1]
# Out:
#           country  year     sex          age  suicides_no  population  \
# 36        Albania  1992    male  35-54 years           12      343800
# 37        Albania  1992    male  15-24 years            9      263700
# 38        Albania  1992    male  55-74 years            5      159500
# 39        Albania  1992    male  25-34 years            7      245500
# 40        Albania  1992  female  15-24 years            7      292400
# ...           ...   ...     ...          ...          ...         ...
# 27683  Uzbekistan  2000  female  25-34 years          106     1864696
# 27684  Uzbekistan  2000  female  55-74 years           48      896059
# 27685  Uzbekistan  2000  female  35-54 years           98     2381166
# 27686  Uzbekistan  2000    male   5-14 years           57     3279407
# 27687  Uzbekistan  2000  female   5-14 years           13     3166259
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# What if we need data between two interval of year, lets create the mask for it:
mask2 = df.year.between(2000, 2010)
df.loc[mask2]
# Out:
#           country  year     sex          age  suicides_no  population  \
# 132       Albania  2000    male  25-34 years           17      232000
# 133       Albania  2000    male  55-74 years           10      177400
# 134       Albania  2000  female    75+ years            2       37800
# 135       Albania  2000    male    75+ years            1       24900
# 136       Albania  2000  female  15-24 years            6      263900
# ...           ...   ...     ...          ...          ...         ...
# 27767  Uzbekistan  2010  female  35-54 years          101     3339076
# 27768  Uzbekistan  2010    male   5-14 years           48     2751752
# 27769  Uzbekistan  2010  female    75+ years            5      322899
# 27770  Uzbekistan  2010  female  55-74 years           16     1161422
# 27771  Uzbekistan  2010  female   5-14 years           30     2627344
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# What if we just need data of two year ?
mask3 = df.year.isin([2000, 2010])
df.loc[mask3]
# Out:
#           country  year     sex          age  suicides_no  population  \
# 132       Albania  2000    male  25-34 years           17      232000
# 133       Albania  2000    male  55-74 years           10      177400
# 134       Albania  2000  female    75+ years            2       37800
# 135       Albania  2000    male    75+ years            1       24900
# 136       Albania  2000  female  15-24 years            6      263900
# ...           ...   ...     ...          ...          ...         ...
# 27767  Uzbekistan  2010  female  35-54 years          101     3339076
# 27768  Uzbekistan  2010    male   5-14 years           48     2751752
# 27769  Uzbekistan  2010  female    75+ years            5      322899
# 27770  Uzbekistan  2010  female  55-74 years           16     1161422
# 27771  Uzbekistan  2010  female   5-14 years           30     2627344
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# What if specifically don't need data of 2000, 2010 year:
f_df = df.loc[~mask3]

# %%
f_df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
f_df.year.unique()
# Out:
# array([1987, 1988, 1989, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 1985, 1986,
#        1990, 1991, 2012, 2013, 2014, 2015, 2011, 2016], dtype=int64)

# %% [markdown]
# ### Now, lets do an Exercise: I need a data of suicides b/w year 2010 and 2014 males and females ?

# %%
# 2010 - 2014:
# Lets see of place: Switzerland: males | females | suicide data:
Mask1 = df.year.between(2010, 2014)
Mask2 = df.sex == 'female'
Mask3 = df.country == 'Switzerland'
Mask4 = df.age == '15-24 years'
f_df_Switzerland = df.loc[Mask1 & Mask2 & Mask3 & Mask4, ['country', 'year', 'sex', 'age', 'suicides_no']]
# ['country', 'year', 'sex', 'age', 'suicides_no'] implies that this much columns we need in our dataFrame.

# %%
f_df_Switzerland
# Out:
#            country  year     sex          age  suicides_no
# 24915  Switzerland  2010  female  15-24 years           15
# 24927  Switzerland  2011  female  15-24 years           15
# 24939  Switzerland  2012  female  15-24 years           10
# 24951  Switzerland  2013  female  15-24 years           17
# 24963  Switzerland  2014  female  15-24 years           14

# %%
f_df_Switzerland.sum().suicides_no
# Out:
# 71
