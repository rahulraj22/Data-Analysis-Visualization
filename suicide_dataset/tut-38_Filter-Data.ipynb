# %%
import pandas as pd

# %%
df = pd.read_csv('suicide_dataset.csv')

# %%
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df.country
# Out:
# 0           Albania
# 1           Albania
# 2           Albania
# 3           Albania
# 4           Albania
#             ...
# 27815    Uzbekistan
# 27816    Uzbekistan
# 27817    Uzbekistan
# 27818    Uzbekistan
# 27819    Uzbekistan
# Name: country, Length: 27820, dtype: object

# %%
type(df.country)
# Out:
# pandas.core.series.Series

# %%
# We will use this function to print unique countries...
df.country.unique()
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
# ...

# %%
# What if we want the data of country lets suppose: Isreal ?
df.country == 'Israel'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27815    False
# 27816    False
# 27817    False
# 27818    False
# 27819    False
# Name: country, Length: 27820, dtype: bool

# %%
type(df.country == 'Israel')
# Out:
# pandas.core.series.Series

# %%
(df.country == 'Israel').dtype
# Out:
# dtype('bool')

# %%
df[df.country == 'Israel']
# Out:
#       country  year     sex          age  suicides_no  population  \
# 12416  Israel  1985    male    75+ years           24       66600
# 12417  Israel  1985    male  55-74 years           48      249100
# 12418  Israel  1985  female    75+ years           10       75500
# 12419  Israel  1985    male  35-54 years           41      396400
# 12420  Israel  1985  female  55-74 years           28      290900
# ...       ...   ...     ...          ...          ...         ...
# 12783  Israel  2015  female  25-34 years           13      581972
# 12784  Israel  2015  female  35-54 years           20      967412
# 12785  Israel  2015  female  15-24 years            8      617440
# 12786  Israel  2015    male   5-14 years            2      770443
# 12787  Israel  2015  female   5-14 years            1      733603
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 12416              36.04   Israel1985         0.768     27,493,591,484
# ...

# %%
# What if just want the data of Israel of year- 2014 ?
mask1 = df.country == 'Ukraine'
mask2 = df.year == 2014
mask3 = df.year == 2015
f_df = df[mask1 & (mask2 | mask3)]  # This will give the results Of 'Israel' but of year 2014 and 2015

# %%
f_df
# Out:
#        country  year     sex          age  suicides_no  population  \
# 26380  Ukraine  2014    male    75+ years          608      919141
# 26381  Ukraine  2014    male  55-74 years         1558     3702856
# 26382  Ukraine  2014    male  35-54 years         2363     5814873
# 26383  Ukraine  2014    male  25-34 years         1302     3543016
# 26384  Ukraine  2014    male  15-24 years          560     2541203
# 26385  Ukraine  2014  female    75+ years          339     2203221
# 26386  Ukraine  2014  female  55-74 years          465     5487093
# 26387  Ukraine  2014  female  35-54 years          423     6365806
# 26388  Ukraine  2014  female  25-34 years          197     3444110
# 26389  Ukraine  2014  female  15-24 years          118     2408666
# 26390  Ukraine  2014    male   5-14 years           21     2074827
# 26391  Ukraine  2014  female   5-14 years           14     1959353
# 26392  Ukraine  2015    male    75+ years          669      942786
# ...

# %%
# what if we don't need this much columns ?
# here we will loc operator:
f_df1 = df.loc[mask1 & (mask2 | mask3), ['country', 'year', 'sex', 'age', 'suicides_no']]

# %%
f_df1
# Out:
#        country  year     sex          age  suicides_no
# 26380  Ukraine  2014    male    75+ years          608
# 26381  Ukraine  2014    male  55-74 years         1558
# 26382  Ukraine  2014    male  35-54 years         2363
# 26383  Ukraine  2014    male  25-34 years         1302
# 26384  Ukraine  2014    male  15-24 years          560
# 26385  Ukraine  2014  female    75+ years          339
# 26386  Ukraine  2014  female  55-74 years          465
# 26387  Ukraine  2014  female  35-54 years          423
# 26388  Ukraine  2014  female  25-34 years          197
# 26389  Ukraine  2014  female  15-24 years          118
# 26390  Ukraine  2014    male   5-14 years           21
# 26391  Ukraine  2014  female   5-14 years           14
# 26392  Ukraine  2015    male    75+ years          669
# 26393  Ukraine  2015    male  55-74 years         1644
# 26394  Ukraine  2015    male  35-54 years         2181
# 26395  Ukraine  2015    male  25-34 years         1114
# ...

# %%
# Here, we see that males and females both coming our dataFrame, what if we need only male data of Israel:
# then , here we will add one more mask:
mask4 = df.sex == 'male'
f_df2 = df.loc[mask1 & mask4 & (mask2 | mask3), ['country', 'year', 'sex', 'age', 'suicides_no']]

# %%
f_df2
# Out:
#        country  year   sex          age  suicides_no
# 26380  Ukraine  2014  male    75+ years          608
# 26381  Ukraine  2014  male  55-74 years         1558
# 26382  Ukraine  2014  male  35-54 years         2363
# 26383  Ukraine  2014  male  25-34 years         1302
# 26384  Ukraine  2014  male  15-24 years          560
# 26390  Ukraine  2014  male   5-14 years           21
# 26392  Ukraine  2015  male    75+ years          669
# 26393  Ukraine  2015  male  55-74 years         1644
# 26394  Ukraine  2015  male  35-54 years         2181
# 26395  Ukraine  2015  male  25-34 years         1114
# 26396  Ukraine  2015  male  15-24 years          507
# 26402  Ukraine  2015  male   5-14 years           33

# %%
# Lets find the sum of all suicides in above dataFrame i.e f_df2:
# Here, 563 is the total no. of suicides happened in 2014 and 2015 by males of Israel
f_df2.sum().suicides_no
# Out:
# 12560

# %%
# Lets see for females suicides data:--
mask5 = df.sex == 'female'
f_df3 = df.loc[mask1 & mask5 & (mask2 | mask3), ['country', 'year', 'sex', 'age', 'suicides_no']]
f_df3
# Out:
#        country  year     sex          age  suicides_no
# 26385  Ukraine  2014  female    75+ years          339
# 26386  Ukraine  2014  female  55-74 years          465
# 26387  Ukraine  2014  female  35-54 years          423
# 26388  Ukraine  2014  female  25-34 years          197
# 26389  Ukraine  2014  female  15-24 years          118
# 26391  Ukraine  2014  female   5-14 years           14
# 26397  Ukraine  2015  female    75+ years          296
# 26398  Ukraine  2015  female  55-74 years          399
# 26399  Ukraine  2015  female  35-54 years          427
# 26400  Ukraine  2015  female  15-24 years          117
# 26401  Ukraine  2015  female  25-34 years          168
# 26403  Ukraine  2015  female   5-14 years           19

# %%
f_df3.sum().suicides_no
# Out:
# 2982
